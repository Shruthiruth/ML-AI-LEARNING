# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_data=[10,20,30]
arr=np.array(my_data)
d={'a':10,'b':20,'c':30}

# %%
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(labels,my_data)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data=[sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1=pd.Series([1,2,3,4],['USA','INDIA','KOREA','UK'])

# %%
ser1
# Out:
# USA      1
# INDIA    2
# KOREA    3
# UK       4
# dtype: int64

# %%
ser2=pd.Series([9,2,6,4],['GERMANY','INDIA','ITALY','JAPAN'])

# %%
ser2
# Out:
# GERMANY    9
# INDIA      2
# ITALY      6
# JAPAN      4
# dtype: int64

# %%
ser2['INDIA']
# Out:
# np.int64(2)

# %%
ser3=pd.Series(data=labels)

# %%
ser3
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser3[0]
# Out:
# 'a'

# %%
ser1+ser2
# Out:
# GERMANY    NaN
# INDIA      4.0
# ITALY      NaN
# JAPAN      NaN
# KOREA      NaN
# UK         NaN
# USA        NaN
# dtype: float64
