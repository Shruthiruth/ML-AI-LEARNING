# %%
1+1
# Out:
# 2

# %%
1*3
# Out:
# 3

# %%
2**4
# Out:
# 16

# %%
1/2.0
# Out:
# 0.5

# %%
2+3*5+5
# Out:
# 22

# %%
4%2
# Out:
# 0

# %%
var= 2
var
# Out:
# 2

# %%
x=2
x=x+x
x
# Out:
# 4

# %%
x
# Out:
# 4

# %%
x
# Out:
# 4

# %%
name_of_var=12

# %%
'single quote' , "this is a string"
# Out:
# ('single quote', 'this is a string')

# %%
num = 12
name = 'Shruthi'
'My number is {} and name is {}'.format(num,name)
# Out:
# 'My number is 12 and name is Shruthi'

# %%
s="hello"
s[0]
# Out:
# 'h'

# %%
s[1:3]
# Out:
# 'el'

# %%
s[0:]
# Out:
# 'hello'

# %%
s[::-1]
# Out:
# 'olleh'

# %%
my_list=['a','b','c']
my_list.append(['d','e'])
my_list
# Out:
# ['a', 'b', 'c', ['d', 'e']]

# %%
my_list=['a','b','c']
my_list.extend(['d','e'])
my_list
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
d={'key':'value','key2':'value2'}
d['key']
# Out:
# 'value'

# %%
d={'k1':{'innerkey':[1,2,3]}}
my_lists=d['k1']['innerkey']

# %%
my_lists[1]
# Out:
# 2

# %%
tuple=(1,2,3)

# %%
tuple
# Out:
# (1, 2, 3)

# %%
tuple[0]
# Out:
# 1

# %%
set([1,2,3,4,423,1])
# Out:
# {1, 2, 3, 4, 423}

# %%
1>=2
# Out:
# False

# %%
1!=1
# Out:
# False

# %%
1<2 and 2<3
# Out:
# True

# %%
if 1==2:
    print('first')
elif 3==3:
    print('middle')
else:
    print('last')
# Out:
# middle

# %%
seq=[1,2,3,4,5]

# %%
for sq in seq:
    print(sq)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while i < 5:
    print('i is {}'.format(i))
    i += 1
# Out:
# i is 1
# i is 2
# i is 3
# i is 4

# %%
for x in range(0,5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x=[1,2,3,4]

# %%
out=[]

# %%
for num in x:
    out.append(num ** 2)

print(out)
# Out:
# [1, 4, 9, 16]

# %%
[num ** 2 for num in x]
# Out:
# [1, 4, 9, 16]

# %%
out=[num ** 2 for num in x]

# %%
out
# Out:
# [1, 4, 9, 16]

# %%
def my_func(param1):
    print(param1)

my_func('hello')
# Out:
# hello

# %%
def square(x):
    """
    a
    b
    c
    d
    """
    return x ** 2

square(3)
# Out:
# 9

# %%
seq=[22,34,5,6]

# %%
list(map(lambda num : num * 2,seq))
# Out:
# [44, 68, 10, 12]

# %%
list(filter(lambda num : num%2==0,seq))
# Out:
# [22, 34, 6]

# %%
s='hellO my name is shruthi'
s.lower()
# Out:
# 'hello my name is shruthi'

# %%
s.upper()
# Out:
# 'HELLO MY NAME IS SHRUTHI'

# %%
s.split("s")
# Out:
# ['hellO my name i', ' ', 'hruthi']

# %%
lsit=[1,2,3]
lsit.pop()
# Out:
# 3

# %%
lsit
# Out:
# [1, 2]

# %%
lsit.append('new')

# %%
lsit
# Out:
# [1, 2, 'new']

# %%
'x' in [1,2,3]
# Out:
# False

# %%
x=[(1,2),(3,4),(5,6)]

# %%
for (a,b) in x:
    print(b)
# Out:
# 2
# 4
# 6
